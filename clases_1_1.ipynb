# %% [markdown]
# <a href="https://colab.research.google.com/github/evelinluz33/python-learn/blob/main/clases_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #clase1

# %% [markdown]
# # Clases 1

# %%
numero=3

# %%
numero
# Out:
# 3

# %%
nombre_apellidos="Amparo Garcia"

# %%
type(numero)
# Out:
# int

# %%
numero2=5.5

# %%
type(numero2)
# Out:
# float

# %%
type(nombre_apellidos)
# Out:
# str

# %%
condicion=True
type(condicion)
# Out:
# bool

# %%
numero1=2
numero2="2"
numero1==numero2
type(str(numero1))
# Out:
# str

# %%
print(f"Mi nombre es {nombre_apellidos}")
# Out:
# Mi nombre es Amparo Garcia

# %%
edad=int(input(f"¿cuantos años tienes{nombre_apellidos}?"))
# Out:
# ¿cuantos años tienesAmparo Garcia?30

# %%
print(f"tienes {edad} años")
# Out:
# tienes 30 años

# %%
type(edad)
# Out:
# int

# %%
numero=20
if numero <3:
  print(f"numero menor que 3")
elif numero <5:
    print(f"numero es mayor o igual que 3 y menor que 5")
elif numero <10:
  print(f"numero es mayor que 3, mayor o igual que 10")
else:
    print("numero mayor o igual que 5")
    print("fin")
# Out:
# numero mayor o igual que 5
# fin

# %%
numero=4
if numero <3:
  print(f"numero menor que 3")
elif numero <5:
    print(f"numero es mayor o igual que 3 y menor que 5")
elif numero <10:
  print(f"numero es mayor que 3, mayor o igual que 10")
else:
    print("numero mayor o igual que 5")
    print("fin")
# Out:
# numero es mayor o igual que 3 y menor que 5

# %%
numero=4
if numero <3:
  print(f"numero menor que 3")
if numero <5:
    print(f"numero es menor que 5")
if numero <10:
  print(f"numero menor que 10")
else:
    print("numero mayor o igual que 5")
    print("fin")
# Out:
# numero es menor que 5
# numero menor que 10

# %% [markdown]
# #ejercicio de una calculadora

# %%
print(f"el resultado es {numero1+int(numero2)} ")
# Out:
# el resultado es 4

# %%
resultado=numero1+int(numero2)

# %%
numero1*int(numero2)
# Out:
# 4

# %%
numero1*int(numero)
# Out:
# 40

# %% [markdown]
# #numero con decimales

# %%
numero1/numero
# Out:
# 0.1

# %% [markdown]
# #numero sin decimales

# %%
numero1//numero
# Out:
# 0

# %%
if numero%2==0:
  print(f"es par")
else:
    print(f"es impar")
# Out:
# es par

# %% [markdown]
# #otra forma de hacerlo impar es:

# %%
numero1//numero
numero=5

# %%
if numero%2==0:
  print(f"es par")
else:
    print(f"es impar")
# Out:
# es impar

# %%
numero=1.25896324

# %%
round(numero,2)
# Out:
# 1.26
